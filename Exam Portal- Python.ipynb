# %% [markdown]
#                                                  ॐ

# %%
class ExamPortal:
    """
    This class is used to conduct Examination for Data Science Students.
    """
    
    def __init__(self,UserID,password):
        self.UserID=UserID
        self.password=password
        print(f"""
        
****************************************************************
|      All India Data Scientist Examination,Delhi              |
|                                                              |
|      Welcomes You                                            | 
|      Mr/Mrs: {UserID} {password} !!!!                          |  
|                                                              | 
****************************************************************""")
    
    def StartExam(self,UserID,password):
        """
        This method is to start the exam. It greets students and Allowing them to start the question paper.
        
        """
        ExamName="All India Data Scientist Examination,Delhi"
        print(f"{ExamName}")
        print(f"""
        ****************************************************************
        Verifing Candidate Deatails.
        
        UserID:  000123{UserID}00
        
        Candidate Name: {UserID} {password}
                                                             ▣..........▣            
        Designation: Data Scientist                          ...*.....*...
                                                             ......^......
        Duration: 10 Min                                     .............
                                                             ▣..........▣
        Center:Velocity Corporate Training Center,Pune           PHOTO
        
        EmailAddress:{UserID}{password}@gmail.com              
       
       
        
        
        
        
        
        ****************************************************************
        """)

        print("All the Best For Examination !!!!\nExam will start soon...")
    
    def QuestionBank(self):
        """
        This Method is for Question bank of examination. It gives A set of question to students the 
        """
        
        Question_No_1="""Question NO 1:Identify the language which is used in data science?
        \n1.C++              \n2.R                 \n3.Java                 \n4.Ruby"""
       
    
        Question_No_2="""Question No 2:\nChoose the correct components of data science.
        \n1.Domain Expertise\n2.Data Engineering \n3.Advanced Computing \n4.All of the Above
        """
    
    
        Question_No_3="""Question No 3:\nWhich of the following is not a part of the data science process?
        \n1.Communication Building\n2.OPerationalize\n3.Model planning\n4.Discovery"""
    
    
        Question_No_4="""Question No 4:\nTotal groups in which data can be characterized is?
        \noptions\n1.1       \n2.2    \n3.3       \n4.4       """
    
    
        Question_No_5="""Question No 5:\nChoose whether the following statement is true or false: 
        Unstructured data is not organized\noptions\n1.True\n2.False\n3.Can not Determind \n4.None Of the Above"""
    
    
        Question_No_6="""Question No 6:\nA column is a  _________ representation of data
        \noptions\n1. Digonal \n2. Vertical \n3. Top \n4. Horizonatal"""
    
    
        Question_No_7="""Question No 7:\nA data frame is an unstructured representation of data
        \noptions\n1.True\n2.False\n3.Can not Determind \n4.None Of the Above"""
    
    
        Question_No_8="""Question No 8:\nAmong the following identify the one in which dimensionality reduction reduces.
        \noptions\n1. Performance     \n2.Entropy        \n3.Stochastics             \n4.Collinarity     """
    
    
        Question_No_9="""Question No 9:\nMachine learning is a subset of which of the following.
        \noptions\n1.Artificial Inteligance \n2.Deep Learing   \n3.Data Engineering    \n4.None of the above    """
    
    
        Question_No_10="""Question No 10:\nFIND-S algorithm ignores?
        \noptions\n1.Positive \n2.Negative\n3.Both \n4.None of the above"""
        
        options="\n1.\n2.\n3.\n4."
    
    
    
    
    
        print(f"""
        \n{Question_No_1}
        \n{Question_No_2}
        \n{Question_No_3}
        \n{Question_No_4}
        \n{Question_No_5}
        \n{Question_No_6}
        \n{Question_No_7}
        \n{Question_No_8}
        \n{Question_No_9}
        \n{Question_No_10}
        """)

    
    
    def Exit(self):
        """
        This Method is used for Exit the Examination.
        """
        print("""
        Successfully Attempted All Question.
        Exam Submitted Successfully !!!! 
        Thank you !!! 😊
        
        """)
              
        
    def Result(self):
        """
        This Method is used for Result declaration of Examination
        
        """
        print("""
        Total Attempt:10
        
        Correct:10
        Wrong:0
        Score:10
        
        Successfully Passed Exam !
        """)
        
        
    
UserID=input("UserID:")
password=input("Password:")
user1=ExamPortal(UserID,password)




while True:
    

                
    options=input("""
****************************************************************
|                                                              |
|       CONTROLS                                               |     
|                                                              |  
|        S=Start the Exam                                      |
|        Q=Start the Question Paper                            |
|        R=Result                                              |
|        E=End the Exam                                        |
|                                                              |  
****************************************************************
   
    
                       """)
    
    
    
    if options=="S" or options=="s":
        user1.StartExam(UserID,password)
    elif options=="Q" or options=="q":
        user1.QuestionBank()
    elif options=="R" or options=="r":
        user1.Result()
    elif options=="E" or options=="e":
        user1.Exit()
        break  
        
    else:
        print("Sorry !!!! \nInvalid Option ")
# Out:
# UserID:Purushottam
# Password:Barde
#
#
# ****************************************************************
# |      All India Data Scientist Examination,Delhi              |
# |                                                              |
# |      Welcomes You                                            |
# |      Mr/Mrs: Purushottam Barde !!!!                          |
# |                                                              |
# ****************************************************************
#
# ****************************************************************
# |                                                              |
# |       CONTROLS                                               |
# |                                                              |
# |        S=Start the Exam                                      |
# |        Q=Start the Question Paper                            |
# |        R=Result                                              |
# ...

# %%
user_data = {"Sakshi Jadhav":{"Name":"Sakshi Jadhav",
                           "UserId":"Sjadhav",
                           "Password":"sj",
                           "gmail":"sakshijadhav8282@gmail.com",
                           },
          "Swati Dhore":{"Name":"Swati Dhore",
                           "UserId":"SDhore",
                           "Password":"sd",
                           "gmail":"swatidhore@gmail.com",
                           },
          "Purushottam Barde":{"Name":"Purushottam Barde",
                           "UserId":"PBarde",
                           "Password":"pb",
                           "gmail":"purushottambarde@gmail.com",
                              },
          "Yashodhan Jagtap":{"Name":"Yashodhan Jagtap",
                           "UserId":"YJagtap",
                           "Password":"yb",
                           "gmail":"yashodhanjagtap@gmail.com",
                             }
}
