# %%
class SBIBank:
    "customer services class for SBI User"
    BankName="SBI Bank,Shivaji Nagar,IE,Nanded"
    
    def __init__(self,name,balance):
        self.name=name
        self.balance=balance    
        print( "🏛     Your using India's Largest Public sector Bank  !    🏛 ")
    
    def balance(self,balance):
        print(f"\n Your Available balance is:{self.balance} INR")
        
    def deposite(self,balance):
        self.balance=self.balance+amount
        print(f"Amount successefully deposited to Your Saving Account.\nAvailable balance in Your Account is:{self.balance} INR")
    
    def withdrawal(self,amount):
        self.balance=self.balance-amount
        print(f"Amount successfuly withdrawed from Your Saving Account.\nAvailable balance in Your Account is:{self.balance} INR")
    
    def transfer(self,amount):
        self.balance=self.balance-transfer
        print(f"successfuly transfered the Amount to Anothers bank Amount.\nAvailable balance in Your Account is:{self.balance} INR")
    
    
    def YONOcash(self):
        print("Stay Ahead! Use YONO (You Need Only One) with SBI ") 
    
    def QRcash(self,amount):
        self.balance=self.balance-amount
        print("Scan a QR code and get Your Amount")
    
    def pinGenrate(self):
        print("Genrate/Update a PIN for New/Old debit card")
    
name=input("Enter Your Good Name: \n Mr/Mrs")
balance=int(input("Enter the Balance Amount: \n INR:"))
user1=SBIBank(name,balance)
print(f"**** Hello {name}, Welcome to {user1.BankName}****")



while True:
    options=input("""Enter the options:::\n \n B==Check Balance \n D==To Deposite an Amount \n W==To withdraw an Amount 
 T==To Transfer Amount \n Y==YONOcash (You need Only One) \n Q==Scan a  QR code to Withdraw Amount
 P==Genrate/Update a Pin \n E==Exit\n
 ********\n
    
                  
                  """)

    if options=="B" or options=="b":
        user1.balance(amount)
        #print(f"The Available balance in Your Account ::: {balance}")

    elif options=="D" or options=="d":
        amount=float(input("Enter the Amount you Want to Deposite to Your saving Account"))
        user1.deposite(amount)
         
    elif options=="w" or options=="W":
        amount=float(input("Enter the Amount you want to Withdraw"))
        user1.withdrawal(amount) 
    elif options=="T" or options=="t":
        amount=float(input("Enter the Amount you want to Transfer"))
        user1.withdrawal(amount)
        
     
    elif options=="Y" or options=="y":
        print(f"The YONO Cash is under maintenance  !!! \n Please visit after Sometime")
    
    elif options=="Q" or options=="q":
        print("Scan this QR Code to Withdraw Amount from your Saving Account")
        print("""      
                   ⩩.....⩩
                   .......
                   .......
                   ⩩.....
        
                                                                """)
        status=eval(input("Press '0' after completing "))
        
        if status==0:
            print("Collect Your Amount")
        else:
            print("Soory !!! \n Please Scan Code Again !")
    
    elif options=="P" or options=="p":
        int(input("New PIN"))
        int(input("Confirm New PIN"))
        print("Changed PIN successfuly")
        
    elif options=="e" or options=="E":
        print("Thank You for Banking With us ! 😊\n\n Rate Your Experience \n   1  2  3  4  5   "  )
        break  
        
    else:
        print("Sorry !!! \nEntered an Invalid Option😔 \nTry Again !")
# Out:
# Enter Your Good Name:
#  Mr/Mrs123
# Enter the Balance Amount:
#  INR:100
# 🏛     Your using India's Largest Public sector Bank  !    🏛
# **** Hello 123, Welcome to SBI Bank,Shivaji Nagar,IE,Nanded****
# Enter the options:::
#
#  B==Check Balance
#  D==To Deposite an Amount
#  W==To withdraw an Amount
#  T==To Transfer Amount
#  Y==YONOcash (You need Only One)
#  Q==Scan a  QR code to Withdraw Amount
#  P==Genrate/Update a Pin
#  E==Exit
#
#  ********
#
#
#
#                   b
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 53
#      51 # controls
#      52     if options=="B" or options=="b":
# ---> 53         user1.balance(amount)
#      54         #print(f"The Available balance in Your Account ::: {balance}")
#      56     elif options=="D" or options=="d":
#
# NameError: name 'amount' is not defined
